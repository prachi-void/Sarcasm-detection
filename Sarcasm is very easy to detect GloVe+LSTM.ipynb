# %% [markdown]
# ## *Tools & libraries*

# %%
import numpy as np 
import pandas as pd 
import os
import re
import matplotlib.pyplot as plt
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, GRU, LSTM, Bidirectional
from keras.layers.embeddings import Embedding
from keras.initializers import Constant
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

# %% [markdown]
# ## *Get the data*

# %%
data_1 = pd.read_json("Sarcasm_Headlines_Dataset.json", lines=True)
data_2 = pd.read_json("Sarcasm_Headlines_Dataset_v2.json", lines=True)
data =  pd.concat([data_1, data_2])
data.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
#
#                                             headline  is_sarcastic
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0

# %%
df=pd.read_csv('personality_essay.csv',sep=",", encoding='cp1252')

# %%
df.head()
# Out:
#            #AUTHID                                               TEXT cEXT  \
# 0  1997_504851.txt  Well, right now I just woke up from a mid-day ...    n
# 1  1997_605191.txt  Well, here we go with the stream of consciousn...    n
# 2  1997_687252.txt  An open keyboard and buttons to push. The thin...    n
# 3  1997_568848.txt  I can't believe it!  It's really happening!  M...    y
# 4  1997_688160.txt  Well, here I go with the good old stream of co...    y
#
#   cNEU cAGR cCON cOPN
# 0    y    y    n    y
# 1    n    y    n    n
# 2    y    n    y    y
# 3    n    y    y    n
# 4    n    y    n    y

# %%
head_lines_ = CleanTokenize(df,'TEXT')
head_lines_[0:10]
# Out:
# [['well',
#   'right',
#   'woke',
#   'midday',
#   'nap',
#   'sort',
#   'weird',
#   'ever',
#   'since',
#   'moved',
#   'texas',
#   'problems',
#   'concentrating',
#   'things',
#   'remember',
#   'starting',
#   'homework',
#   'grade',
#   'soon',
#   'clock',
#   'struck',
#   'stopping',
#   'done',
#   'course',
#   'easier',
#   'still',
#   'moved',
#   'homework',
#   'got',
#   'little',
#   'challenging',
#   'lot',
#   'busy',
#   'work',
#   'decided',
#   'spend',
#   'hours',
#   'getting',
#   'thing',
#   'always',
#   'paid',
#   'attention',
#   'class',
#   'plain',
#   'knew',
#   'stuff',
#   'look',
#   'back',
#   'really',
#   'worked',
#   'hard',
#   'stayed',
#   'track',
#   'last',
#   'two',
#   'years',
#   'without',
#   'getting',
#   'lazy',
#   'would',
#   'genius',
#   'hey',
#   'good',
#   'late',
#   'correct',
#   'past',
#   'really',
#   'know',
#   'stay',
#   'focused',
#   'n',
#   'future',
#   'one',
#   'thing',
#   'know',
#   'people',
#   'say',
#   'bc',
#   'live',
#   'campus',
#   'concentrate',
#   'b',
#   'would',
#   'easier',
#   'alas',
#   'living',
#   'home',
#   'watchful',
#   'eye',
#   'parents',
#   'little',
#   'nagging',
#   'sister',
#   'nags',
#   'nags',
#   'nags',
#   'get',
#   'point',
#   'another',
#   'thing',
#   'hassle',
#   'go',
#   'way',
#   'back',
#   'school',
#   'go',
#   'library',
#   'study',
#   'need',
#   'move',
#   'know',
#   'tell',
#   'get',
#   'wrong',
#   'see',
#   'coming',
#   'want',
#   'move',
#   'need',
#   'get',
#   'away',
#   'sheltered',
#   'much',
#   'worry',
#   'world',
#   'thing',
#   'ask',
#   'keep',
#   'room',
#   'clean',
#   'help',
#   'business',
#   'even',
#   'need',
#   'got',
#   'enough',
#   'money',
#   'ut',
#   'live',
#   'dorm',
#   'apartment',
#   'next',
#   'semester',
#   'think',
#   'take',
#   'advantage',
#   'topic',
#   'went',
#   'sixth',
#   'street',
#   'last',
#   'night',
#   'blast',
#   'havent',
#   'long',
#   'know',
#   'love',
#   'austin',
#   'much',
#   'lived',
#   'va',
#   'used',
#   'go',
#   'dc',
#   'time',
#   'blast',
#   'many',
#   'students',
#   'running',
#   'around',
#   'night',
#   'want',
#   'fun',
#   'know',
#   'responsible',
#   'enough',
#   'able',
#   'fun',
#   'keep',
#   'priorities',
#   'straight',
#   'living',
#   'home',
#   'go',
#   'without',
#   'asking',
#   'coming',
#   'back',
#   'questions',
#   'wish',
#   'could',
#   'treated',
#   'like',
#   'responsible',
#   'person',
#   'sister',
#   'screwed',
#   'went',
#   'crazy',
#   'second',
#   'moved',
#   'college',
#   'messed',
#   'whole',
#   'college',
#   'career',
#   'partying',
#   'much',
#   'ultimate',
#   'reason',
#   'want',
#   'go',
#   'fun',
#   'little',
#   'anymore',
#   'need',
#   'let',
#   'go',
#   'explore',
#   'world',
#   'indian',
#   'indian',
#   'culture',
#   'indian',
#   'values',
#   'go',
#   'fun',
#   'mean',
#   'sense',
#   'meeting',
#   'people',
#   'going',
#   'people',
#   'partying',
#   'plain',
#   'fun',
#   'school',
#   'difficult',
#   'already',
#   'somehow',
#   'think',
#   'freedom',
#   'put',
#   'pressure',
#   'better',
#   'school',
#   'bc',
#   'parents',
#   'ultimately',
#   'expect',
#   'well',
#   'fun',
#   'writing',
#   'know',
#   'go',
#   'anything',
#   'writing',
#   'helped',
#   'get',
#   'thoughts',
#   'order',
#   'hope',
#   'fun',
#   'reading',
#   'good',
#   'luck',
#   'tas'],
#  ['well',
#   'go',
#   'stream',
#   'consciousness',
#   'essay',
#   'used',
#   'things',
#   'like',
#   'high',
#   'school',
#   'sometimes',
#   'pretty',
#   'interesting',
#   'often',
#   'find',
#   'lack',
#   'things',
#   'say',
#   'normally',
#   'consider',
#   'someone',
#   'gets',
#   'straight',
#   'point',
#   'wonder',
#   'hit',
#   'enter',
#   'time',
#   'send',
#   'back',
#   'front',
#   'maybe',
#   'fix',
#   'later',
#   'friend',
#   'playing',
#   'guitar',
#   'room',
#   'sort',
#   'playing',
#   'anyway',
#   'like',
#   'messing',
#   'still',
#   'learning',
#   'theres',
#   'drawing',
#   'wall',
#   'next',
#   'comic',
#   'book',
#   'characters',
#   'think',
#   'sure',
#   'since',
#   'kept',
#   'comics',
#   'heard',
#   'sound',
#   'icq',
#   'chat',
#   'program',
#   'internet',
#   'know',
#   'much',
#   'really',
#   'explain',
#   'well',
#   'anyway',
#   'hope',
#   'done',
#   'time',
#   'another',
#   'friend',
#   'comes',
#   'nice',
#   'talk',
#   'went',
#   'home',
#   'weekend',
#   'labor',
#   'day',
#   'brother',
#   'didnt',
#   'go',
#   'sure',
#   'reason',
#   'go',
#   'guess',
#   'hmm',
#   'start',
#   'wow',
#   'long',
#   'line',
#   'guess',
#   'change',
#   'later',
#   'okay',
#   'running',
#   'things',
#   'talk',
#   'found',
#   'happens',
#   'lot',
#   'conversation',
#   'interesting',
#   'person',
#   'guess',
#   'well',
#   'know',
#   'something',
#   'working',
#   'class',
#   'might',
#   'help',
#   'phone',
#   'rang',
#   'get',
#   'guy',
#   'playing',
#   'guitar',
#   'answered',
#   'roommate',
#   'suitemate',
#   'came',
#   'started',
#   'reading',
#   'uncomfortable',
#   'bathroom',
#   'know',
#   'really',
#   'boring',
#   'piece',
#   'literature',
#   'never',
#   'realized',
#   'dull',
#   'everyday',
#   'thoughts',
#   'keep',
#   'mind',
#   'constantly',
#   'moving',
#   'like',
#   'isnt',
#   'really',
#   'time',
#   'stop',
#   'think',
#   'deeply',
#   'things',
#   'wonder',
#   'long',
#   'going',
#   'think',
#   'ten',
#   'minutes',
#   'second',
#   'line',
#   'sad',
#   'well',
#   'really',
#   'considering',
#   'long',
#   'lines',
#   'anyway',
#   'wonder',
#   'going',
#   'rest',
#   'night',
#   'guess',
#   'theres',
#   'always',
#   'homework',
#   'guess',
#   'see',
#   'seat',
#   'uncomfortable',
#   'back',
#   'sort',
#   'hurts',
#   'think',
#   'going',
#   'arthritis',
#   'get',
#   'older',
#   'always',
#   'thought',
#   'wouldnt',
#   'like',
#   'grow',
#   'old',
#   'old',
#   'suppose',
#   'always',
#   'active',
#   'person',
#   'fear',
#   'growing',
#   'old',
#   'think',
#   'guess',
#   'go',
#   'away',
#   'age',
#   'gradually',
#   'know',
#   'well',
#   'would',
#   'deal',
#   'paralysis',
#   'accident',
#   'though',
#   'long',
#   'god',
#   'friends',
#   'around',
#   'okay',
#   'though',
#   'pretty',
#   'thirsty',
#   'right',
#   'isnt',
#   'much',
#   'drink',
#   'around',
#   'room',
#   'ultimate',
#   'frisbee',
#   'havent',
#   'played',
#   'summer',
#   'fun',
#   'game',
#   'tiring',
#   'shape',
#   'would',
#   'like',
#   'get',
#   'better',
#   'shape',
#   'hate',
#   'running',
#   'dull',
#   'hmmm',
#   'almost',
#   'minutes',
#   'lets',
#   'see',
#   'make',
#   'next',
#   'line',
#   'short',
#   'reachable',
#   'goals',
#   'whatever',
#   'anyway',
#   'else',
#   'tonight',
#   'guess',
#   'could',
#   'read',
#   'shirt',
#   'smells',
#   'like',
#   'dinner',
#   'pretty',
#   'disgusting',
#   'need',
#   'wake',
#   'class',
#   'tomorrow',
#   'remember',
#   'wasnt',
#   'early',
#   'well',
#   'made',
#   'next',
#   'line',
#   'proud',
#   'sarcasm',
#   'way',
#   'wonder',
#   'suppose',
#   'right',
#   'thing',
#   'narrative',
#   'oh',
#   'well',
#   'late',
#   'time',
#   'head',
#   'next',
#   'time',
#   'good',
#   'bye',
#   'good',
#   'luck',
#   'know'],
#  ['open',
#   'keyboard',
#   'buttons',
#   'push',
#   'thing',
#   'finally',
#   'worked',
#   'need',
#   'use',
#   'periods',
#   'commas',
#   'thinks',
#   'double',
#   'space',
#   'period',
#   'help',
#   'put',
#   'spaces',
#   'words',
#   'happy',
#   'little',
#   'assignment',
#   'jibberjabber',
#   'babble',
#   'babble',
#   'babble',
#   'relaxing',
#   'minutes',
#   'feel',
#   'silly',
#   'grammatically',
#   'incorrect',
#   'linked',
#   'unknown',
#   'reader',
#   'graduate',
#   'student',
#   'absurd',
#   'job',
#   'type',
#   'jabber',
#   'think',
#   'dinoflagellates',
#   'sunflower',
#   'crosses',
#   'fiberglass',
#   'added',
#   'lips',
#   'via',
#   'clove',
#   'cigarettes',
#   'think',
#   'things',
#   'shouldnt',
#   'thinking',
#   'know',
#   'shouldnt',
#   'thinking',
#   'writing',
#   'lets',
#   'say',
#   'thoughts',
#   'solidify',
#   'lodge',
#   'back',
#   'behind',
#   'tongue',
#   'maybe',
#   'somewhere',
#   'point',
#   'hiding',
#   'dinoflaghelates',
#   'protistas',
#   'sea',
#   'weed',
#   'think',
#   'san',
#   'luiz',
#   'valley',
#   'think',
#   'mushrooms',
#   'cow',
#   'shit',
#   'think',
#   'ticos',
#   'think',
#   'chiggers',
#   'living',
#   'legs',
#   'itch',
#   'coat',
#   'clear',
#   'nail',
#   'polish',
#   'hopes',
#   'suffocate',
#   'bugs',
#   'living',
#   'legs',
#   'remember',
#   'marco',
#   'remember',
#   'ecuador',
#   'think',
#   'thoughts',
#   'supposed',
#   'assignment',
#   'thoughts',
#   'wonder',
#   'think',
#   'sentences',
#   'wonder',
#   'affect',
#   'slowish',
#   'typing',
#   'stream',
#   'consciousness',
#   'wonder',
#   'way',
#   'typing',
#   'speed',
#   'measured',
#   'study',
#   'link',
#   'generalization',
#   'dorky',
#   'psyc',
#   'students',
#   'green',
#   'table',
#   'kitchen',
#   'makes',
#   'want',
#   'vomit',
#   'orange',
#   'absurd',
#   'color',
#   'wish',
#   'wasnt',
#   'united',
#   'state',
#   'greencard',
#   'runs',
#   'years',
#   'wonder',
#   'hope',
#   'dr',
#   'linder',
#   'gets',
#   'back',
#   'lab',
#   'really',
#   'need',
#   'find',
#   'funds',
#   'pay',
#   'may',
#   'go',
#   'back',
#   'library',
#   'brainless',
#   'job',
#   'nothingness',
#   'would',
#   'make',
#   'wallow',
#   'world',
#   'boredom',
#   'isnt',
#   'entirely',
#   'bad',
#   'need',
#   'focus',
#   'school',
#   'organics',
#   'period',
#   'two',
#   'spaces',
#   'period',
#   'mistakes',
#   'want',
#   'eat',
#   'hungry',
#   'wonder',
#   'many',
#   'people',
#   'talk',
#   'food',
#   'little',
#   'computer',
#   'ramblings',
#   'feel',
#   'open',
#   'happy',
#   'edit',
#   'type',
#   'type',
#   'know',
#   'think',
#   'hannah',
#   'imi',
#   'osdprey',
#   'house',
#   'remember',
#   'went',
#   'spiders',
#   'hurt',
#   'wall',
#   'pain',
#   'place',
#   'painted',
#   'clouds',
#   'ceiling',
#   'blue',
#   'walls',
#   'obnoxious',
#   'carey',
#   'sex',
#   'sex',
#   'sex',
#   'yeah',
#   'strange',
#   'assignment',
#   'portonoys',
#   'complaint',
#   'ringing',
#   'head',
#   'eager',
#   'finish',
#   'start',
#   'bell',
#   'tolls',
#   'get',
#   'bio',
#   'carbon',
#   'atoms',
#   'bonds',
#   'orbitals',
#   'thinking',
#   'electron',
#   'configuration',
#   'surrounds',
#   'last',
#   'letter',
#   'first',
#   'name',
#   'think',
#   'must',
#   'granted',
#   'full',
#   'orbital',
#   'one',
#   'one',
#   'spinning',
#   'opposite',
#   'directions',
#   'thinking',
#   'scottish',
#   'poetry',
#   'mike',
#   'kilt',
#   'guitar',
#   'slowly',
#   'slowly',
#   'slowly',
#   'learning',
#   'play',
#   'wonder',
#   'goes',
#   'study',
#   'wonder',
#   'happy',
#   'little',
#   'bored',
#   'entertained',
#   'grad',
#   'students',
#   'scan',
#   'words',
#   'wonder',
#   'mess',
#   'study',
#   'random',
#   'words',
#   'like',
#   'know',
#   'wish',
#   'things',
#   'easier',
#   'wish',
#   'keeping',
#   'eye',
#   'clock',
#   'wondering',
#   'long',
#   'typing',
#   'wishing',
#   'finished',
#   'need',
#   'find',
#   'work',
#   'botany',
#   'lab',
#   'ils',
#   'belly',
#   'flamenco',
#   'bjork',
#   'rozamond',
#   'cockrill',
#   'kickin',
#   'saratoga',
#   'springs',
#   'hate',
#   'mollys',
#   'cat',
#   'wish',
#   'could',
#   'exchanged',
#   'worthwhile',
#   'ferret',
#   'type',
#   'type',
#   'type',
#   'managed',
#   'waste',
#   'minutes',
#   'time',
#   'think',
#   'knows',
#   'write',
#   'took',
#   'minutes',
#   'write',
#   'minutes',
#   'type',
#   'thinking',
#   'nothing',
#   'wishing',
#   'financial',
#   'aid',
#   'would',
#   'come',
#   'way',
#   'need',
#   'job',
#   'sprinkling',
#   'time',
#   'time',
#   'go',
#   'sign',
#   'outta',
#   'trees'],
#  ['believe',
#   'really',
#   'happening',
#   'pulse',
#   'racing',
#   'like',
#   'mad',
#   'like',
#   'finally',
#   'know',
#   'feels',
#   'like',
#   'steps',
#   'wonder',
#   'going',
#   'get',
#   'sleep',
#   'tonight',
#   'sure',
#   'well',
#   'course',
#   'million',
#   'deadlines',
#   'meet',
#   'tomorrow',
#   'late',
#   'anyway',
#   'oh',
#   'excited',
#   'yes',
#   'yes',
#   'believe',
#   'finally',
#   'happening',
#   'wait',
#   'calm',
#   'arent',
#   'officially',
#   'couple',
#   'yet',
#   'end',
#   'liking',
#   'would',
#   'horrible',
#   'oh',
#   'great',
#   'wonder',
#   'long',
#   'take',
#   'finish',
#   'calculus',
#   'problems',
#   'get',
#   'done',
#   'always',
#   'amy',
#   'believe',
#   'bob',
#   'really',
#   'miracle',
#   'worker',
#   'things',
#   'turn',
#   'right',
#   'owe',
#   'ever',
#   'repay',
#   'wonder',
#   'steve',
#   'malaysia',
#   'right',
#   'entire',
#   'month',
#   'likely',
#   'clean',
#   'refrigerator',
#   'omigosh',
#   'food',
#   'lunch',
#   'tomorrow',
#   'ever',
#   'say',
#   'perfect',
#   'every',
#   'way',
#   'imaginable',
#   'important',
#   'think',
#   'way',
#   'well',
#   'maybe',
#   'perfect',
#   'certainly',
#   'dynamic',
#   'would',
#   'ever',
#   'thought',
#   'good',
#   'things',
#   'indeed',
#   'come',
#   'wait',
#   'oh',
#   'remember',
#   'sign',
#   'poster',
#   'made',
#   'tomorrow',
#   'morning',
#   'hope',
#   'steves',
#   'alarm',
#   'clock',
#   'reliable',
#   'oversleep',
#   'would',
#   'tragic',
#   'slept',
#   'til',
#   'noon',
#   'missed',
#   'lunch',
#   'thank',
#   'goodness',
#   'portia',
#   'coming',
#   'along',
#   'definitely',
#   'need',
#   'support',
#   'well',
#   'bobs',
#   'take',
#   'away',
#   'tension',
#   'put',
#   'ease',
#   'rehearse',
#   'say',
#   'beforehand',
#   'things',
#   'get',
#   'better',
#   'right',
#   'hopefully',
#   'oh',
#   'nervous',
#   'maybe',
#   'even',
#   'ok',
#   'world',
#   'humans',
#   'put',
#   'torture',
#   'maybe',
#   'love',
#   'really',
#   'worth'],
#  ['well',
#   'go',
#   'good',
#   'old',
#   'stream',
#   'consciousness',
#   'assignment',
#   'feel',
#   'like',
#   'back',
#   'freshman',
#   'hs',
#   'english',
#   'class',
#   'bad',
#   'thing',
#   'mind',
#   'english',
#   'teacher',
#   'freshman',
#   'year',
#   'made',
#   'us',
#   'assignments',
#   'constantly',
#   'mine',
#   'always',
#   'completely',
#   'ridiculous',
#   'like',
#   'wow',
#   'really',
#   'hungry',
#   'wish',
#   'could',
#   'go',
#   'taco',
#   'bell',
#   'really',
#   'point',
#   'except',
#   'busy',
#   'work',
#   'psychology',
#   'class',
#   'though',
#   'see',
#   'reasoning',
#   'behind',
#   'assignment',
#   'like',
#   'letting',
#   'mind',
#   'go',
#   'free',
#   'putting',
#   'random',
#   'thoughts',
#   'writing',
#   'could',
#   'big',
#   'help',
#   'figuring',
#   'psychological',
#   'screwup',
#   'well',
#   'true',
#   'want',
#   'yall',
#   'getting',
#   'wrong',
#   'idea',
#   'today',
#   'first',
#   'day',
#   'class',
#   'really',
#   'nut',
#   'case',
#   'people',
#   'may',
#   'think',
#   'really',
#   'normal',
#   'kind',
#   'gal',
#   'actually',
#   'texas',
#   'guess',
#   'normal',
#   'like',
#   'eat',
#   'biscuits',
#   'gravy',
#   'breakfast',
#   'country',
#   'fried',
#   'steak',
#   'fried',
#   'okra',
#   'dinner',
#   'connecticut',
#   'even',
#   'okra',
#   'much',
#   'less',
#   'worship',
#   'like',
#   'kind',
#   'vegetable',
#   'goddess',
#   'mind',
#   'starting',
#   'go',
#   'blankperformance',
#   'pressure',
#   'guess',
#   'spot',
#   'herei',
#   'want',
#   'bored',
#   'reading',
#   'ever',
#   'get',
#   'around',
#   'reading',
#   'well',
#   'going',
#   'stress',
#   'yet',
#   'probably',
#   'going',
#   'listen',
#   'random',
#   'incoherent',
#   'babbling',
#   'paragraphs',
#   'computers',
#   'big',
#   'old',
#   'pain',
#   'ass',
#   'smf',
#   'sure',
#   'got',
#   'bajillion',
#   'computers',
#   'unfortunately',
#   'got',
#   'bajillion',
#   'students',
#   'trying',
#   'use',
#   'time',
#   'think',
#   'spending',
#   'quite',
#   'late',
#   'late',
#   'nights',
#   'computer',
#   'center',
#   'get',
#   'stuff',
#   'done',
#   'yippee',
#   'college',
#   'aboutlate',
#   'nights',
#   'libraries',
#   'yeah',
#   'right',
#   'point',
#   'even',
#   'know',
#   'college',
#   'probably',
#   'shouldnt',
#   'say',
#   'anything',
#   'though',
#   'seeing',
#   'going',
#   'write',
#   'another',
#   'one',
#   'thingys',
#   'days',
#   'topic',
#   'college',
#   'blah',
#   'blah',
#   'blah',
#   'believe',
#   'actually',
#   'assignment',
#   'day',
#   'assigned',
#   'go',
#   'talk',
#   'dedication',
#   'really',
#   'believe',
#   'high',
#   'school',
#   'procrastination',
#   'middle',
#   'name',
#   'first',
#   'name',
#   'second',
#   'semester',
#   'free',
#   'periods',
#   'day',
#   'actual',
#   'classes',
#   'didnt',
#   'damn',
#   'thing',
#   'great',
#   'unfortunately',
#   'going',
#   'work',
#   'much',
#   'harder',
#   'ut',
#   'get',
#   'studying',
#   'skills',
#   'back',
#   'par',
#   'high',
#   'school',
#   'trip',
#   'could',
#   'wait',
#   'get',
#   'hated',
#   'school',
#   'town',
#   'everything',
#   'except',
#   'friends',
#   'course',
#   'family',
#   'moved',
#   'right',
#   'graduation',
#   'learned',
#   'real',
#   'quick',
#   'worse',
#   'places',
#   'old',
#   'town',
#   'least',
#   'back',
#   'home',
#   'friends',
#   'boyfriend',
#   'piece',
#   'crap',
#   'car',
#   'knew',
#   'moved',
#   'friends',
#   'life',
#   'car',
#   'nothing',
#   'worked',
#   'day',
#   'though',
#   'ready',
#   'whole',
#   'college',
#   'thing',
#   'austin',
#   'seems',
#   'like',
#   'fun',
#   'city',
#   'might',
#   'actually',
#   'enjoy',
#   'spending',
#   'next',
#   'four',
#   'years',
#   'oh',
#   'yeah',
#   'subject',
#   'four',
#   'years',
#   'professors',
#   'administrators',
#   'give',
#   'speeches',
#   'stuff',
#   'always',
#   'make',
#   'sound',
#   'like',
#   'college',
#   'like',
#   'years',
#   'sorry',
#   'plan',
#   'graduating',
#   'years',
#   'problem',
#   'people',
#   'graduate',
#   'years',
#   'get',
#   'offense',
#   'yall',
#   'reading',
#   'took',
#   'like',
#   'years',
#   'undergrad',
#   'work',
#   'trying',
#   'knock',
#   'trying',
#   'figure',
#   'well',
#   'exactly',
#   'minutes',
#   'started',
#   'nifty',
#   'little',
#   'piece',
#   'writing',
#   'makes',
#   'sense',
#   'point',
#   'really',
#   'sure',
#   'fulfilled',
#   'assignment',
#   'like',
#   'supposed',
#   'analyze',
#   'personal',
#   'stream',
#   'consciousness',
#   'took',
#   'means',
#   'regarding',
#   'personality',
#   'guess',
#   'could',
#   'say',
#   'mind',
#   'works',
#   'mysterious',
#   'ways',
#   'even',
#   'essay',
#   'seems',
#   'illogically',
#   'connected',
#   'see',
#   'patterns',
#   'yeah',
#   'went',
#   'back',
#   'tried',
#   'read',
#   'got',
#   'give',
#   'suggestion',
#   'assignments',
#   'make',
#   'box',
#   'writing',
#   'box',
#   'see',
#   'whole',
#   'line',
#   'writing',
#   'one',
#   'time',
#   'without',
#   'scroll',
#   'across',
#   'real',
#   'big',
#   'pain',
#   'sure',
#   'big',
#   'pain',
#   'trying',
#   'read',
#   'unless',
#   'course',
#   'read',
#   'see',
#   'whole',
#   'line',
#   'know',
#   'suggestion',
#   'thanks',
#   'taking',
#   'time',
#   'give',
#   'us',
#   'opportunity',
#   'get',
#   'easy',
#   'final',
#   'grade',
#   'writing',
#   'assignments'],
#  ['today',
#   'turn',
#   'music',
#   'today',
#   'went',
#   'kvrx',
#   'meeting',
#   'hopefully',
#   'radio',
#   'show',
#   'know',
#   'talk',
#   'considered',
#   'great',
#   'depth',
#   'jeez',
#   'songs',
#   'starts',
#   'quietly',
#   'cool',
#   'beginning',
#   'start',
#   'louder',
#   'oh',
#   'well',
#   'perfect',
#   'roommate',
#   'playing',
#   'game',
#   'plays',
#   'game',
#   'much',
#   'spends',
#   'much',
#   'time',
#   'get',
#   'homework',
#   'know',
#   'song',
#   'rather',
#   'erotic',
#   'deep',
#   'disturbing',
#   'way',
#   'decide',
#   'whether',
#   'actually',
#   'want',
#   'study',
#   'medical',
#   'technology',
#   'love',
#   'many',
#   'things',
#   'form',
#   'chemistry',
#   'mycology',
#   'religious',
#   'studies',
#   'speaking',
#   'good',
#   'time',
#   'psa',
#   'meeting',
#   'pagan',
#   'student',
#   'alliance',
#   'ahh',
#   'got',
#   'ta',
#   'love',
#   'screech',
#   'chairs',
#   'let',
#   'push',
#   'back',
#   'ahhhhh',
#   'well',
#   'oh',
#   'yeah',
#   'meeting',
#   'met',
#   'several',
#   'people',
#   'caleb',
#   'seems',
#   'rather',
#   'worried',
#   'one',
#   'women',
#   'though',
#   'bound',
#   'like',
#   'wise',
#   'unable',
#   'speak',
#   'ill',
#   'well',
#   'charge',
#   'running',
#   'booth',
#   'monday',
#   'tuesday',
#   'song',
#   'one',
#   'team',
#   'roommate',
#   'winning',
#   'yeesh',
#   'well',
#   'guess',
#   'enjoys',
#   'typing',
#   'rather',
#   'poor',
#   'assignment',
#   'taking',
#   'long',
#   'time',
#   'minutes',
#   'lalalalalalalal',
#   'yes',
#   'meeting',
#   'talked',
#   'shamanism',
#   'apparently',
#   'comes',
#   'siberian',
#   'word',
#   'several',
#   'hundred',
#   'different',
#   'shamanic',
#   'following',
#   'world',
#   'due',
#   'vast',
#   'number',
#   'tribes',
#   'speckle',
#   'world',
#   'peter',
#   'steele',
#   'sexy',
#   'voice',
#   'would',
#   'love',
#   'make',
#   'love',
#   'song',
#   'well',
#   'much',
#   'info',
#   'dtos',
#   'fun',
#   'ellipses',
#   'word',
#   'fun',
#   'think',
#   'perhaps',
#   'slowly',
#   'running',
#   'things',
#   'say',
#   'song',
#   'reminds',
#   'young',
#   'age',
#   'riding',
#   'car',
#   'talking',
#   'family',
#   'streetlights',
#   'bright',
#   'back',
#   'things',
#   'happy',
#   'perhaps',
#   'remember',
#   'well',
#   'car',
#   'full',
#   'us',
#   'dog',
#   'wasnt',
#   'around',
#   'isnt',
#   'anymore',
#   'either',
#   'epilepsy',
#   'taken',
#   'incarnation',
#   'wonder',
#   'know',
#   'miss',
#   'wish',
#   'could',
#   'find',
#   'possibly',
#   'clairvoyance',
#   'course',
#   'assumption',
#   'spirits',
#   'equal',
#   'know',
#   'yes',
#   'shall',
#   'ever',
#   'childhood',
#   'bears',
#   'interesting',
#   'mark',
#   'past',
#   'fuzziness',
#   'seem',
#   'recollect',
#   'exact',
#   'details',
#   'like',
#   'others',
#   'brown',
#   'fuzzy',
#   'best',
#   'word',
#   'really',
#   'suck',
#   'wonder',
#   'cd',
#   'still',
#   'lying',
#   'answering',
#   'machine',
#   'love',
#   'bright',
#   'circling',
#   'colors',
#   'interest',
#   'psychotic',
#   'manner',
#   'hypnotic',
#   'manner',
#   'calm',
#   'like',
#   'calm',
#   'sedate',
#   'though',
#   'activity',
#   'occasion',
#   'good',
#   'grey',
#   'good',
#   'color',
#   'neutral',
#   'yes',
#   'passive',
#   'though',
#   'passive',
#   'good',
#   'taoism',
#   'theres',
#   'philosophy',
#   'believe',
#   'nothing',
#   'everything',
#   'interesting',
#   'currently',
#   'reading',
#   'aleister',
#   'crowley',
#   'hermetic',
#   'order',
#   'seems',
#   'rather',
#   'interesting',
#   'though',
#   'bit',
#   'abnormal',
#   'almost',
#   'eccentric',
#   'side',
#   'remember',
#   'reading',
#   'stories',
#   'spiders',
#   'milkmen',
#   'fields',
#   'roses',
#   'daisies',
#   'yeah',
#   'daisies',
#   'looking',
#   'upon',
#   'daisies',
#   'look',
#   'want',
#   'past',
#   'life',
#   'regression',
#   'find',
#   'wonder',
#   'anyone',
#   'famous',
#   'popular',
#   'wow',
#   'saying',
#   'rather',
#   'strange',
#   'things',
#   'interesting',
#   'didnt',
#   'head',
#   'hurts',
#   'room',
#   'hot',
#   'would',
#   'like',
#   'stop',
#   'minutes',
#   'left',
#   'nothing',
#   'say',
#   'except',
#   'watching',
#   'fingers',
#   'press',
#   'buttons',
#   'rather',
#   'enjoyable',
#   'activity',
#   'press',
#   'slowly',
#   'heavy',
#   'sometimes',
#   'fast',
#   'lithe',
#   'mean',
#   'light',
#   'yeah',
#   'light',
#   'hope',
#   'right',
#   'putting',
#   'consciousness',
#   'record',
#   'others',
#   'read',
#   'guess',
#   'cool',
#   'interesting',
#   'though',
#   'said',
#   'little',
#   'wonder',
#   'saying',
#   'ahh',
#   'three',
#   'minutes',
#   'passed',
#   'typing',
#   'ill',
#   'slow',
#   'halt'],
#  ['stream',
#   'consciousness',
#   'write',
#   'supposed',
#   'kind',
#   'direction',
#   'supposed',
#   'write',
#   'exactly',
#   'thinking',
#   'feels',
#   'like',
#   'strange',
#   'assignment',
#   'homework',
#   'seems',
#   'pretty',
#   'easy',
#   'actually',
#   'would',
#   'pretty',
#   'intense',
#   'worth',
#   'however',
#   'much',
#   'worth',
#   'hmm',
#   'reason',
#   'blanked',
#   'seems',
#   'like',
#   'thinking',
#   'nothing',
#   'oh',
#   'well',
#   'lets',
#   'see',
#   'happened',
#   'today',
#   'lucked',
#   'econ',
#   'quiz',
#   'actually',
#   'able',
#   'guess',
#   'way',
#   'chances',
#   'faith',
#   'definitely',
#   'pays',
#   'always',
#   'say',
#   'important',
#   'faith',
#   'motto',
#   'life',
#   'faith',
#   'fun',
#   'life',
#   'funny',
#   'thing',
#   'one',
#   'minute',
#   'gone',
#   'next',
#   'like',
#   'louie',
#   'lug',
#   'mcgurg',
#   'example',
#   'died',
#   'tragically',
#   'happened',
#   'somebody',
#   'stepped',
#   'fingers',
#   'killed',
#   'well',
#   'hanging',
#   'story',
#   'hotel',
#   'time',
#   'poor',
#   'lug',
#   'poor',
#   'mrs',
#   'lug',
#   'streets',
#   'selling',
#   'apples',
#   'point',
#   'lug',
#   'plan',
#   'ahead',
#   'government',
#   'got',
#   'everything',
#   'oscar',
#   'damn',
#   'intense',
#   'movie',
#   'seems',
#   'difficult',
#   'figure',
#   'thinking',
#   'wen',
#   'try',
#   'blank',
#   'keep',
#   'trying',
#   'figure',
#   'stream',
#   'consciences',
#   'life',
#   'good',
#   'entire',
#   'internet',
#   'business',
#   'pretty',
#   'cool',
#   'never',
#   'would',
#   'thought',
#   'could',
#   'write',
#   'paper',
#   'send',
#   'teacher',
#   'pushing',
#   'submit',
#   'button',
#   'wonder',
#   'much',
#   'longer',
#   'writing',
#   'ten',
#   'minutes',
#   'left',
#   'everyone',
#   'always',
#   'asks',
#   'thinking',
#   'sitting',
#   'thinking',
#   'usually',
#   'say',
#   'nothing',
#   'want',
#   'tell',
#   'trying',
#   'think',
#   'thinking',
#   'getting',
#   'nothing',
#   'cricket',
#   'great',
#   'sport',
#   'going',
#   'sahara',
#   'cup',
#   'going',
#   'played',
#   'canada',
#   'india',
#   'vc',
#   'paistan',
#   'one',
#   'biggest',
#   'cricketing',
#   'rivalries',
#   'world',
#   'team',
#   'pak',
#   'going',
#   'victorious',
#   'aamir',
#   'sohai',
#   'great',
#   'cricketer',
#   'believe',
#   'dropped',
#   'team',
#   'granted',
#   'little',
#   'form',
#   'would',
#   'taken',
#   'indian',
#   'crap',
#   'bowlers',
#   'around',
#   'park',
#   'back',
#   'beginning',
#   'seem',
#   'kind',
#   'silly',
#   'hope',
#   'point',
#   'wonder',
#   'body',
#   'actually',
#   'going',
#   'read',
#   'reason',
#   'doubt',
#   'whoever',
#   'reading',
#   'though',
#   'feel',
#   'sorry',
#   'lot',
#   'peoples',
#   'garbage',
#   'talk',
#   'read',
#   'maybe',
#   'isnt',
#   'idea',
#   'screen',
#   'really',
#   'weird',
#   'come',
#   'three',
#   'lines',
#   'popped',
#   'writing',
#   'minutes',
#   'kind',
#   'ploy',
#   'see',
#   'written',
#   'believe',
#   'thought',
#   'fact',
#   'noticed',
#   'much',
#   'screen',
#   'interesting',
#   'getting',
#   'tired',
#   'typing',
#   'waiting',
#   'final',
#   'minutes',
#   'tick',
#   'away',
#   'hope',
#   'gain',
#   'something',
#   'think',
#   'actually',
#   'might',
#   'idea',
#   'thinking',
#   'quitting',
#   'early',
#   'kind',
#   'device',
#   'told',
#   'long',
#   'actually',
#   'pretty',
#   'scary',
#   'god',
#   'knows',
#   'technology',
#   'nowadays',
#   'anyway',
#   'hope',
#   'enjoy',
#   'reading',
#   'quite',
#   'possible',
#   'enjoyed',
#   'writing',
#   'fun',
#   'relaxing',
#   'write',
#   'something',
#   'without',
#   'go',
#   'back',
#   'proofread',
#   'seems',
#   'like',
#   'expert',
#   'typer',
#   'actually',
#   'anyway',
#   'minutes',
#   'faith',
#   'fun',
#   'read',
#   'give',
#   'even',
#   'though',
#   'matter',
#   'completion',
#   'grade',
#   'stuff',
#   'amazing',
#   'classes'],
#  ['usenet',
#   'site',
#   'piece',
#   'garbage',
#   'sent',
#   'first',
#   'required',
#   'message',
#   'another',
#   'persons',
#   'name',
#   'slot',
#   'probably',
#   'get',
#   'credit',
#   'worse',
#   'yet',
#   'access',
#   'computers',
#   'suck',
#   'bad',
#   'enough',
#   'wait',
#   'line',
#   'use',
#   'one',
#   'well',
#   'got',
#   'get',
#   'perhaps',
#   'bring',
#   'old',
#   'one',
#   'home',
#   'seems',
#   'different',
#   'even',
#   'though',
#   'basically',
#   'everything',
#   'desk',
#   'home',
#   'right',
#   'antique',
#   'desk',
#   'spent',
#   'hour',
#   'hour',
#   'perfecting',
#   'work',
#   'listening',
#   'favorite',
#   'music',
#   'right',
#   'hear',
#   'journey',
#   'string',
#   'right',
#   'stereo',
#   'hall',
#   'would',
#   'shut',
#   'paying',
#   'anyway',
#   'come',
#   'miles',
#   'upon',
#   'miles',
#   'earning',
#   'right',
#   'squander',
#   'stupid',
#   'sound',
#   'effects',
#   'loud',
#   'music',
#   'wanted',
#   'hear',
#   'inspector',
#   'gadget',
#   'simpson',
#   'would',
#   'change',
#   'channel',
#   'get',
#   'watch',
#   'v',
#   'minutes',
#   'day',
#   'certainly',
#   'want',
#   'choose',
#   'roommate',
#   'choose',
#   'inconsiderate',
#   'shmuck',
#   'hall',
#   'get',
#   'speaking',
#   'halls',
#   'turn',
#   'tight',
#   'one',
#   'computer',
#   'room',
#   'used',
#   'feel',
#   'plush',
#   'carpet',
#   'feet',
#   'cold',
#   'refreshing',
#   'taste',
#   'coke',
#   'walked',
#   'quickly',
#   'room',
#   'begin',
#   'work',
#   'night',
#   'shows',
#   'missed',
#   'missed',
#   'countless',
#   'mindless',
#   'hours',
#   'television',
#   'pure',
#   'mindnumbing',
#   'entertainment',
#   'beat',
#   'see',
#   'industrial',
#   'carpet',
#   'wall',
#   'right',
#   'plush',
#   'bed',
#   'jake',
#   'used',
#   'love',
#   'gave',
#   'nip',
#   'scratched',
#   'ears',
#   'night',
#   'reminds',
#   'bumpkin',
#   'exterminator',
#   'came',
#   'large',
#   'clean',
#   'inviting',
#   'house',
#   'thought',
#   'bob',
#   'cat',
#   'vet',
#   'called',
#   'bigboned',
#   'mean',
#   'obese',
#   'ate',
#   'bowls',
#   'day',
#   'pound',
#   'cat',
#   'gut',
#   'reminds',
#   'cats',
#   'twenty',
#   'pounder',
#   'human',
#   'equivalent',
#   'pounds',
#   'theatre',
#   'rocked',
#   'pei',
#   'awesome',
#   'guy',
#   'v',
#   'eccentric',
#   'freak',
#   'myerson',
#   'cool',
#   'could',
#   'go',
#   'hot',
#   'chocolate',
#   'like',
#   'christmas',
#   'musical',
#   'went',
#   'guy',
#   'pretty',
#   'short',
#   'mom',
#   'worked',
#   'bald',
#   'bowling',
#   'alley',
#   'floor',
#   'play',
#   'pool',
#   'go',
#   'insane',
#   'basement',
#   'used',
#   'smell',
#   'musty',
#   'sleepovers',
#   'fun'],
#  ['really',
#   'unsure',
#   'assignment',
#   'afraid',
#   'wont',
#   'able',
#   'think',
#   'things',
#   'say',
#   'minutes',
#   'start',
#   'mad',
#   'right',
#   'last',
#   'night',
#   'allison',
#   'rebecca',
#   'stephanie',
#   'went',
#   'paul',
#   'trey',
#   'go',
#   'coon',
#   'hunting',
#   'allison',
#   'went',
#   'last',
#   'weekend',
#   'fun',
#   'anyway',
#   'drove',
#   'hour',
#   'get',
#   'killeen',
#   'bridge',
#   'hang',
#   'prostitutes',
#   'later',
#   'first',
#   'went',
#   'house',
#   'trashy',
#   'rebecca',
#   'didnt',
#   'even',
#   'want',
#   'go',
#   'inside',
#   'use',
#   'bathroom',
#   'went',
#   'outside',
#   'gross',
#   'drove',
#   'place',
#   'hunting',
#   'made',
#   'us',
#   'get',
#   'bed',
#   'truck',
#   'trey',
#   'drove',
#   'mph',
#   'flying',
#   'around',
#   'played',
#   'never',
#   'game',
#   'didnt',
#   'realize',
#   'rebecca',
#   'stephanie',
#   'like',
#   'cool',
#   'go',
#   'bridge',
#   'smells',
#   'like',
#   'shit',
#   'rotting',
#   'carcasses',
#   'something',
#   'scared',
#   'stephanie',
#   'telling',
#   'ghost',
#   'story',
#   'bridge',
#   'trey',
#   'turned',
#   'around',
#   'went',
#   'bridge',
#   'times',
#   'scared',
#   'get',
#   'field',
#   'paul',
#   'already',
#   'asshole',
#   'took',
#   'dogs',
#   'allison',
#   'begun',
#   'paul',
#   'jodi',
#   'trey',
#   'flip',
#   'left',
#   'walker',
#   'bitch',
#   'spice',
#   'truck',
#   'start',
#   'walking',
#   'toward',
#   'creek',
#   'turned',
#   'raw',
#   'sewage',
#   'refused',
#   'go',
#   'paul',
#   'screamed',
#   'bitch',
#   'didnt',
#   'give',
#   'fuck',
#   'went',
#   'back',
#   'woods',
#   'flashlight',
#   'could',
#   'get',
#   'truck',
#   'never',
#   'scarred',
#   'entire',
#   'life',
#   'prayed',
#   'whole',
#   'time',
#   'took',
#   'spice',
#   'afraid',
#   'going',
#   'get',
#   'raped',
#   'murdered',
#   'something',
#   'bawling',
#   'trying',
#   'tell',
#   'parents',
#   'telepathy',
#   'loved',
#   'would',
#   'miss',
#   'going',
#   'die',
#   'heard',
#   'voice',
#   'yelling',
#   'name',
#   'asking',
#   'help',
#   'trey',
#   'coming',
#   'back',
#   'make',
#   'sure',
#   'okay',
#   'happy',
#   'minutes',
#   'later',
#   'others',
#   'came',
#   'back',
#   'looked',
#   'like',
#   'night',
#   'living',
#   'dead',
#   'briars',
#   'thorns',
#   'hair',
#   'told',
#   'wished',
#   'would',
#   'stayed',
#   'got',
#   'bras',
#   'panties',
#   'clothes',
#   'soaked',
#   'sewage',
#   'drove',
#   'home',
#   'whole',
#   'time',
#   'paul',
#   'bitching',
#   'allison',
#   'everything',
#   'treating',
#   'like',
#   'shit',
#   'think',
#   'could',
#   'much',
#   'better',
#   'love',
#   'told',
#   'get',
#   'home',
#   'class',
#   'missed',
#   'much',
#   'already',
#   'made',
#   'basically',
#   'consuming',
#   'today',
#   'sorry',
#   'wanted'],
#  ['today',
#   'tough',
#   'day',
#   'believed',
#   'failed',
#   'talk',
#   'asweenee',
#   'girl',
#   'ever',
#   'much',
#   'power',
#   'probably',
#   'sun',
#   'kicking',
#   'wait',
#   'go',
#   'football',
#   'game',
#   'saturday',
#   'ut',
#   'definitely',
#   'going',
#   'beat',
#   'rutgers',
#   'bc',
#   'rutgers',
#   'lost',
#   'last',
#   'week',
#   'weak',
#   'team',
#   'points',
#   'calculus',
#   'class',
#   'going',
#   'boring',
#   'tomorrow',
#   'professor',
#   'going',
#   'continue',
#   'lecture',
#   'limits',
#   'hope',
#   'get',
#   'homework',
#   'else',
#   'busy',
#   'wed',
#   'night',
#   'phone',
#   'next',
#   'door',
#   'driving',
#   'crazy',
#   'kyle',
#   'ringer',
#   'high',
#   'need',
#   'buy',
#   'bush',
#   'cd',
#   'soon',
#   'songs',
#   'cd',
#   'pump',
#   'let',
#   'overcome',
#   'fear',
#   'talking',
#   'asweenee',
#   'hope',
#   'remembers',
#   'concert',
#   'knows',
#   'weird',
#   'freak',
#   'neal',
#   'seems',
#   'enjoy',
#   'studying',
#   'chemistry',
#   'reason',
#   'extra',
#   'problems',
#   'even',
#   'though',
#   'due',
#   'guess',
#   'feels',
#   'insecure',
#   'ability',
#   'chemistry',
#   'hope',
#   'giants',
#   'win',
#   'next',
#   'week',
#   'jacksonville',
#   'good',
#   'game',
#   'knowing',
#   'luck',
#   'even',
#   'televise',
#   'game',
#   'cares',
#   'cowboys',
#   'tonight',
#   'want',
#   'email',
#   'steve',
#   'tell',
#   'difficult',
#   'conquest',
#   'girlfriend',
#   'maybe',
#   'things',
#   'clear',
#   'next',
#   'days',
#   'finally',
#   'courage',
#   'good',
#   'socializing',
#   'never',
#   'froze',
#   'like',
#   'long',
#   'time',
#   'maybe',
#   'thinking',
#   'much',
#   'screwing',
#   'know',
#   'better',
#   'baseball',
#   'season',
#   'almost',
#   'near',
#   'homestretch',
#   'hope',
#   'yankees',
#   'catch',
#   'orioles',
#   'go',
#   'back',
#   'world',
#   'series',
#   'parents',
#   'probably',
#   'trying',
#   'call',
#   'right',
#   'wondering',
#   'phone',
#   'line',
#   'busy',
#   'wondering',
#   'linh',
#   'adjusting',
#   'rice',
#   'hope',
#   'getting',
#   'depressed',
#   'seeing',
#   'paul',
#   'help',
#   'get',
#   'hard',
#   'time',
#   'glad',
#   'summer',
#   'needed',
#   'good',
#   'friend',
#   'could',
#   'understand',
#   'really',
#   'miss',
#   'lot',
#   'time',
#   'know',
#   'fine',
#   'sound',
#   'like',
#   'parents',
#   'wonder',
#   'craigs',
#   'drive',
#   'minnesota',
#   'dad',
#   'probably',
#   'giving',
#   'lecture',
#   'happened',
#   'summer',
#   'room',
#   'needs',
#   'ac',
#   'ac',
#   'idiot',
#   'next',
#   'door',
#   'blaring',
#   'music',
#   'spice',
#   'girls',
#   'suck',
#   'going',
#   'listen',
#   'music',
#   'least',
#   'show',
#   'taste',
#   'think',
#   'starting',
#   'feel',
#   'effects',
#   'hunan',
#   'chicken',
#   'stuffed',
#   'dog',
#   'looks',
#   'like',
#   'snoopy',
#   'neal',
#   'must',
#   'attached',
#   'toy']]

# %% [markdown]
# ## *Clean the data*

# %%
def clean_text(text):
    text = text.lower()
    
    pattern = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    text = pattern.sub('', text)
    text = " ".join(filter(lambda x:x[0]!='@', text.split()))
    emoji = re.compile("["
                           u"\U0001F600-\U0001FFFF"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    
    text = emoji.sub(r'', text)
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)        
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text) 
    text = re.sub(r"\'ll", " will", text)  
    text = re.sub(r"\'ve", " have", text)  
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"don't", "do not", text)
    text = re.sub(r"did't", "did not", text)
    text = re.sub(r"can't", "can not", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"couldn't", "could not", text)
    text = re.sub(r"have't", "have not", text)
    text = re.sub(r"[,.\"\'!@#$%^&*(){}?/;`~:<>+=-]", "", text)
    return text

# %%
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

def CleanTokenize(df,str):
    head_lines = list()
    lines = df[str].values.tolist()

    for line in lines:
        line = clean_text(line)
        # tokenize the text
        tokens = word_tokenize(line)
        # remove puntuations
        table = str.maketrans('', '', string.punctuation)
        stripped = [w.translate(table) for w in tokens]
        # remove non alphabetic characters
        words = [word for word in stripped if word.isalpha()]
        stop_words = set(stopwords.words("english"))
        # remove stop words
        words = [w for w in words if not w in stop_words]
        head_lines.append(words)
    return head_lines

head_lines = CleanTokenize(data,'headline')
head_lines[0:10]
# Out:
# [['former',
#   'versace',
#   'store',
#   'clerk',
#   'sues',
#   'secret',
#   'black',
#   'code',
#   'minority',
#   'shoppers'],
#  ['roseanne',
#   'revival',
#   'catches',
#   'thorny',
#   'political',
#   'mood',
#   'better',
#   'worse'],
#  ['mom',
#   'starting',
#   'fear',
#   'sons',
#   'web',
#   'series',
#   'closest',
#   'thing',
#   'grandchild'],
#  ['boehner',
#   'wants',
#   'wife',
#   'listen',
#   'come',
#   'alternative',
#   'debtreduction',
#   'ideas'],
#  ['jk', 'rowling', 'wishes', 'snape', 'happy', 'birthday', 'magical', 'way'],
#  ['advancing', 'worlds', 'women'],
#  ['fascinating', 'case', 'eating', 'labgrown', 'meat'],
#  ['ceo', 'send', 'kids', 'school', 'work', 'company'],
#  ['top', 'snake', 'handler', 'leaves', 'sinking', 'huckabee', 'campaign'],
#  ['fridays', 'morning', 'email', 'inside', 'trumps', 'presser', 'ages']]

# %% [markdown]
# ## *Visualize the most occuring words*

# %%
from collections import Counter
from wordcloud import WordCloud, ImageColorGenerator
pos_data = data.loc[data['is_sarcastic'] == 1]
pos_head_lines = CleanTokenize(pos_data)
pos_lines = [j for sub in pos_head_lines for j in sub] 
word_could_dict=Counter(pos_lines)

wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(word_could_dict)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-e15a9863399e> in <module>
#       1 from collections import Counter
# ----> 2 from wordcloud import WordCloud, ImageColorGenerator
#       3 pos_data = data.loc[data['is_sarcastic'] == 1]
#       4 pos_head_lines = CleanTokenize(pos_data)
#       5 pos_lines = [j for sub in pos_head_lines for j in sub]
#
# ModuleNotFoundError: No module named 'wordcloud'

# %% [markdown]
# ## *Train-test split*

# %%
validation_split = 0.2
max_length = 25


tokenizer_obj = Tokenizer()
tokenizer_obj.fit_on_texts(head_lines)
sequences = tokenizer_obj.texts_to_sequences(head_lines)

word_index = tokenizer_obj.word_index
print("unique tokens - ",len(word_index))
vocab_size = len(tokenizer_obj.word_index) + 1
print('vocab size -', vocab_size)

lines_pad = pad_sequences(sequences, maxlen=max_length, padding='post')
sentiment =  data['is_sarcastic'].values

indices = np.arange(lines_pad.shape[0])
np.random.shuffle(indices)
lines_pad = lines_pad[indices]
sentiment = sentiment[indices]

num_validation_samples = int(validation_split * lines_pad.shape[0])

X_train_pad = lines_pad[:-num_validation_samples]
y_train = sentiment[:-num_validation_samples]
X_test_pad = lines_pad[-num_validation_samples:]
y_test = sentiment[-num_validation_samples:]
# Out:
# unique tokens -  28657
# vocab size - 28658

# %%
print('Shape of X_train_pad:', X_train_pad.shape)
print('Shape of y_train:', y_train.shape)

print('Shape of X_test_pad:', X_test_pad.shape)
print('Shape of y_test:', y_test.shape)
# Out:
# Shape of X_train_pad: (44263, 25)
# Shape of y_train: (44263,)
# Shape of X_test_pad: (11065, 25)
# Shape of y_test: (11065,)

# %% [markdown]
# ## *Load GloVe model*

# %%
embeddings_index = {}
embedding_dim = 100

f = open(os.path.join( 'glove.twitter.27B.100d.txt'), encoding = "utf-8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 1193514 word vectors.

# %% [markdown]
# ## *Build the embedding layer*

# %%
embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
c = 0
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        c+=1
        embedding_matrix[i] = embedding_vector
print(c)
# Out:
# 24755

# %%
embedding_layer = Embedding(len(word_index) + 1,
                            embedding_dim,
                            weights=[embedding_matrix],
                            input_length=max_length,
                            trainable=False)

# %% [markdown]
# ## *Build the RNN*

# %%
model = Sequential()
model.add(embedding_layer)
model.add(LSTM(64, dropout=0.2, recurrent_dropout=0.25))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

print('Summary of the built model...')
print(model.summary())
# Out:
# Summary of the built model...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 25, 100)           2865800
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                42240
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 2,908,105
# Trainable params: 42,305
# Non-trainable params: 2,865,800
# _________________________________________________________________
# None

# %% [markdown]
# ## *Training*

# %%
history = model.fit(X_train_pad, y_train, batch_size=32, epochs=25, validation_data=(X_test_pad, y_test), verbose=2)
# Out:
# Epoch 1/25
# 1384/1384 - 38s - loss: 0.5136 - acc: 0.7466 - val_loss: 0.4246 - val_acc: 0.8042
# Epoch 2/25
# 1384/1384 - 37s - loss: 0.4306 - acc: 0.8013 - val_loss: 0.3810 - val_acc: 0.8340
# Epoch 3/25
# 1384/1384 - 37s - loss: 0.3917 - acc: 0.8245 - val_loss: 0.3611 - val_acc: 0.8428
# Epoch 4/25
# 1384/1384 - 36s - loss: 0.3643 - acc: 0.8380 - val_loss: 0.3416 - val_acc: 0.8567
# Epoch 5/25
# 1384/1384 - 37s - loss: 0.3378 - acc: 0.8518 - val_loss: 0.3234 - val_acc: 0.8606
# Epoch 6/25
# 1384/1384 - 36s - loss: 0.3167 - acc: 0.8620 - val_loss: 0.3297 - val_acc: 0.8541
# Epoch 7/25
# 1384/1384 - 36s - loss: 0.2994 - acc: 0.8719 - val_loss: 0.3068 - val_acc: 0.8758
# Epoch 8/25
# 1384/1384 - 36s - loss: 0.2866 - acc: 0.8764 - val_loss: 0.2862 - val_acc: 0.8818
# Epoch 9/25
# 1384/1384 - 36s - loss: 0.2736 - acc: 0.8834 - val_loss: 0.2874 - val_acc: 0.8793
# Epoch 10/25
# 1384/1384 - 36s - loss: 0.2622 - acc: 0.8896 - val_loss: 0.2648 - val_acc: 0.8912
# Epoch 11/25
# 1384/1384 - 37s - loss: 0.2548 - acc: 0.8935 - val_loss: 0.2710 - val_acc: 0.8886
# Epoch 12/25
# 1384/1384 - 36s - loss: 0.2452 - acc: 0.8975 - val_loss: 0.2650 - val_acc: 0.8932
# Epoch 13/25
# 1384/1384 - 36s - loss: 0.2389 - acc: 0.9012 - val_loss: 0.2537 - val_acc: 0.8976
# Epoch 14/25
# 1384/1384 - 37s - loss: 0.2303 - acc: 0.9047 - val_loss: 0.2507 - val_acc: 0.9010
# Epoch 15/25
# 1384/1384 - 36s - loss: 0.2247 - acc: 0.9075 - val_loss: 0.2393 - val_acc: 0.9039
# Epoch 16/25
# 1384/1384 - 36s - loss: 0.2184 - acc: 0.9091 - val_loss: 0.2450 - val_acc: 0.9046
# Epoch 17/25
# 1384/1384 - 36s - loss: 0.2127 - acc: 0.9131 - val_loss: 0.2684 - val_acc: 0.8962
# Epoch 18/25
# 1384/1384 - 36s - loss: 0.2082 - acc: 0.9159 - val_loss: 0.2432 - val_acc: 0.9036
# Epoch 19/25
# 1384/1384 - 36s - loss: 0.2045 - acc: 0.9169 - val_loss: 0.2273 - val_acc: 0.9147
# Epoch 20/25
# 1384/1384 - 36s - loss: 0.2024 - acc: 0.9173 - val_loss: 0.2224 - val_acc: 0.9144
# Epoch 21/25
# 1384/1384 - 36s - loss: 0.1975 - acc: 0.9188 - val_loss: 0.2127 - val_acc: 0.9190
# Epoch 22/25
# 1384/1384 - 36s - loss: 0.1922 - acc: 0.9231 - val_loss: 0.2089 - val_acc: 0.9197
# Epoch 23/25
# 1384/1384 - 36s - loss: 0.1910 - acc: 0.9226 - val_loss: 0.2199 - val_acc: 0.9140
# Epoch 24/25
# 1384/1384 - 36s - loss: 0.1868 - acc: 0.9245 - val_loss: 0.2205 - val_acc: 0.9212
# Epoch 25/25
# 1384/1384 - 36s - loss: 0.1860 - acc: 0.9249 - val_loss: 0.2160 - val_acc: 0.9213

# %% [markdown]
# ## *Visualize the learning*

# %%
# Plot results
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'g', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# <hr>
# <h2><i>Can this model detect sarcasms?</i></h2>

# %%
def predict_sarcasm(s):
    x_final = pd.DataFrame({"headline":[s]})
    test_lines = CleanTokenize(x_final)
    test_sequences = tokenizer_obj.texts_to_sequences(test_lines)
    test_review_pad = pad_sequences(test_sequences, maxlen=max_length, padding='post')
    pred = model.predict(test_review_pad)
    pred*=100
    if pred[0][0]>=50: return "It's a sarcasm!" 
    else: return "It's not a sarcasm."

# %% [markdown]
# ### *Correct guesses*

# %%
predict_sarcasm("I was depressed. He asked me to be happy. I am not depressed anymore.")
# Out:
# "It's a sarcasm!"

# %%
predict_sarcasm("You just broke my car window. Great job.")
# Out:
# "It's a sarcasm!"

# %%
predict_sarcasm("You just saved my dog's life. Thanks a million.")
# Out:
# "It's not a sarcasm."

# %%
predict_sarcasm("I want a million dollars!")
# Out:
# "It's not a sarcasm."

# %%
predict_sarcasm("I just won a million dollars!")
# Out:
# "It's a sarcasm!"

# %% [markdown]
# ### *Incorrect guesses*

# %%
predict_sarcasm("His name is Bob. He is a nice person.")
# Out:
# "It's a sarcasm!"

# %%
predict_sarcasm("Sarcasm is very easy to detect.")
# Out:
# "It's not a sarcasm."
